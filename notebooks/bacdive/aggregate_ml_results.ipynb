# %%
import pathlib

import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %%
output_folder = pathlib.Path("../data/outputs/")

# %%
def get_scores(folder: pathlib.Path) -> pd.DataFrame | None:
    scores = {}
    scores_file = folder / "scores.csv"
    if not scores_file.is_file():
        return None
    scores_df = pd.read_csv(scores_file, index_col=0)
    return scores_df

# %%
scores_data_list = []
untrained_data_list = []
for category in output_folder.iterdir():
    if not category.is_dir():
        continue
    for name in category.iterdir():
        if not name.is_dir():
            continue
        scores_df = get_scores(name)
        if scores_df is None:
            untrained_data_list.append({
                "category": category,
                "name": name,
            })
        else:
            scores_data_list.append(scores_df)

untrained_df = pd.DataFrame(untrained_data_list)
all_scores_df = pd.concat(scores_data_list)

# %%
untrained_df
# Out:
#                         category  \
# 0  ../data/outputs/carbon_source
# 1  ../data/outputs/carbon_source
# 2  ../data/outputs/carbon_source
# 3  ../data/outputs/carbon_source
# 4  ../data/outputs/carbon_source
# 5  ../data/outputs/carbon_source
# 6  ../data/outputs/carbon_source
# 7        ../data/outputs/unknown
# 8        ../data/outputs/unknown
#
#                                              name
# 0         ../data/outputs/carbon_source/ornithine
# 1           ../data/outputs/carbon_source/leucine
# 2           ../data/outputs/carbon_source/proline
# 3        ../data/outputs/carbon_source/asparagine
# 4         ../data/outputs/carbon_source/histidine
# 5            ../data/outputs/carbon_source/fucose
# 6         ../data/outputs/carbon_source/threonine
# 7              ../data/outputs/unknown/unnamed_13
# 8  ../data/outputs/unknown/ncbi_tax_id-subspecies

# %%
all_scores_df
# Out:
#                                                  name      category  accuracy  \
# myo-inositol-NA                          myo-inositol           NaN  0.592857
# sucrose-NA                                    sucrose           NaN  0.652778
# glucose-NA                                    glucose           NaN  0.621622
# xylose-NA                                      xylose           NaN  0.571429
# arabinose-NA                                arabinose           NaN  0.737589
# ...                                               ...           ...       ...
# L-histidine-assimilation                  L-histidine  assimilation  0.720930
# raffinose-assimilation                      raffinose  assimilation  0.666667
# acetate-assimilation                          acetate  assimilation  0.739130
# potassium_gluconate-assimilation  potassium_gluconate  assimilation  0.647059
# L-fucose-assimilation                        L-fucose  assimilation  0.538462
#
#                                   balanced_accuracy        f1  precision  \
# myo-inositol-NA                            0.589231  0.551181   0.564516
# sucrose-NA                                 0.637962  0.709302   0.685393
# glucose-NA                                 0.688889  0.735849   0.951220
# xylose-NA                                  0.564626  0.433962   0.359375
# arabinose-NA                               0.733709  0.767296   0.772152
# ...                                             ...       ...        ...
# L-histidine-assimilation                   0.692857  0.600000   0.600000
# raffinose-assimilation                     0.652520  0.533333   0.470588
# acetate-assimilation                       0.739130  0.739130   0.739130
# potassium_gluconate-assimilation           0.660394  0.594595   0.511628
# L-fucose-assimilation                      0.540584  0.400000   0.315789
#
#                                     recall  matthews_corrcoef
# myo-inositol-NA                   0.538462           0.179180
# sucrose-NA                        0.734940           0.280618
# glucose-NA                        0.600000           0.248408
# xylose-NA                         0.547619           0.118899
# arabinose-NA                      0.762500           0.466558
# ...                                    ...                ...
# L-histidine-assimilation          0.600000           0.385714
# raffinose-assimilation            0.615385           0.287298
# acetate-assimilation              0.739130           0.478261
# potassium_gluconate-assimilation  0.709677           0.308843
# L-fucose-assimilation             0.545455           0.073076
#
# [245 rows x 8 columns]

# %%
all_scores_melt = all_scores_df.melt(id_vars=["name", "category"], var_name='score', value_name='value')
all_scores_melt
# Out:
#                      name      category              score     value
# 0            myo-inositol           NaN           accuracy  0.592857
# 1                 sucrose           NaN           accuracy  0.652778
# 2                 glucose           NaN           accuracy  0.621622
# 3                  xylose           NaN           accuracy  0.571429
# 4               arabinose           NaN           accuracy  0.737589
# ...                   ...           ...                ...       ...
# 1465          L-histidine  assimilation  matthews_corrcoef  0.385714
# 1466            raffinose  assimilation  matthews_corrcoef  0.287298
# 1467              acetate  assimilation  matthews_corrcoef  0.478261
# 1468  potassium_gluconate  assimilation  matthews_corrcoef  0.308843
# 1469             L-fucose  assimilation  matthews_corrcoef  0.073076
#
# [1470 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.swarmplot(data=all_scores_melt, x="score", y="value", hue="category", size=3)
plt.xticks(rotation=45);
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0);

# %%
g = sns.catplot(data=all_scores_melt, x="score", y="value", hue="score", col="category", kind="swarm",  col_wrap=3)
for ax in g.axes.flat:
    ax.tick_params(axis='x', rotation=45, which="both");
g.figure.tight_layout();
g.add_legend();

# %%
top20_scores_df = all_scores_df.sort_values(by=["matthews_corrcoef", "balanced_accuracy"], ascending=[False, False]).head(20)
top20_scores_df
# Out:
#                                                                        name  \
# gram_positive-unknown                                         gram_positive
# L-rhamnose-fermentation                                          L-rhamnose
# spore_formation-unknown                                     spore_formation
# D-mannitol-fermentation                                          D-mannitol
# myo-inositol-fermentation                                      myo-inositol
# cellobiose-fermentation                                          cellobiose
# L-arabinose-fermentation                                        L-arabinose
# melibiose-fermentation                                            melibiose
# D-xylose-builds_acid_from                                          D-xylose
# decanoate-assimilation                                            decanoate
# D-glucose-fermentation                                            D-glucose
# palatinose-builds_acid_from                                      palatinose
# L-arabinose-builds_acid_from                                    L-arabinose
# methyl_beta-D-xylopyranoside-builds_acid_from  methyl_beta-D-xylopyranoside
# sorbitol-fermentation                                              sorbitol
# amygdalin-fermentation                                            amygdalin
# oxygen_tolerance_aerobe-unknown                     oxygen_tolerance_aerobe
# tryptophan-energy_source                                         tryptophan
# gluconate-assimilation                                            gluconate
# arginine-hydrolysis                                                arginine
#
#                                                        category  accuracy  \
# gram_positive-unknown                                   unknown  0.979943
# L-rhamnose-fermentation                            fermentation  0.961905
# spore_formation-unknown                                 unknown  0.949219
# D-mannitol-fermentation                            fermentation  0.912548
# myo-inositol-fermentation                          fermentation  0.910714
# cellobiose-fermentation                            fermentation  0.923077
# L-arabinose-fermentation                           fermentation  0.904762
# melibiose-fermentation                             fermentation  0.877193
# D-xylose-builds_acid_from                      builds_acid_from  0.877622
# decanoate-assimilation                             assimilation  0.890667
# D-glucose-fermentation                             fermentation  0.882136
# palatinose-builds_acid_from                    builds_acid_from  0.884615
# L-arabinose-builds_acid_from                   builds_acid_from  0.857527
# methyl_beta-D-xylopyranoside-builds_acid_from  builds_acid_from  0.955801
# sorbitol-fermentation                              fermentation  0.858491
# amygdalin-fermentation                             fermentation  0.842593
# oxygen_tolerance_aerobe-unknown                         unknown  0.935657
# tryptophan-energy_source                          energy_source  0.918056
# gluconate-assimilation                             assimilation  0.836120
# arginine-hydrolysis                                  hydrolysis  0.856164
#
#                                                balanced_accuracy        f1  \
# gram_positive-unknown                                   0.981428  0.972621
# L-rhamnose-fermentation                                 0.961874  0.960784
# spore_formation-unknown                                 0.938570  0.911565
# D-mannitol-fermentation                                 0.896106  0.882051
# myo-inositol-fermentation                               0.937500  0.864865
# cellobiose-fermentation                                 0.951613  0.842105
# L-arabinose-fermentation                                0.904762  0.919355
# melibiose-fermentation                                  0.880297  0.875000
# D-xylose-builds_acid_from                               0.880429  0.852321
# decanoate-assimilation                                  0.875202  0.812785
# D-glucose-fermentation                                  0.869155  0.822222
# palatinose-builds_acid_from                             0.928571  0.769231
# L-arabinose-builds_acid_from                            0.867028  0.808664
# methyl_beta-D-xylopyranoside-builds_acid_from           0.806439  0.714286
# sorbitol-fermentation                                   0.853702  0.805195
# amygdalin-fermentation                                  0.843793  0.834951
# oxygen_tolerance_aerobe-unknown                         0.880108  0.963746
# tryptophan-energy_source                                0.908998  0.703518
# gluconate-assimilation                                  0.835687  0.821818
# arginine-hydrolysis                                     0.858872  0.759725
#
#                                                precision    recall  \
# gram_positive-unknown                           0.958869  0.986772
# L-rhamnose-fermentation                         0.960784  0.960784
# spore_formation-unknown                         0.909502  0.913636
# D-mannitol-fermentation                         0.966292  0.811321
# myo-inositol-fermentation                       0.761905  1.000000
# cellobiose-fermentation                         0.727273  1.000000
# L-arabinose-fermentation                        0.934426  0.904762
# melibiose-fermentation                          0.830508  0.924528
# D-xylose-builds_acid_from                       0.814516  0.893805
# decanoate-assimilation                          0.787611  0.839623
# D-glucose-fermentation                          0.813187  0.831461
# palatinose-builds_acid_from                     0.625000  1.000000
# L-arabinose-builds_acid_from                    0.736842  0.896000
# methyl_beta-D-xylopyranoside-builds_acid_from   0.833333  0.625000
# sorbitol-fermentation                           0.775000  0.837838
# amygdalin-fermentation                          0.811321  0.860000
# oxygen_tolerance_aerobe-unknown                 0.978528  0.949405
# tryptophan-energy_source                        0.578512  0.897436
# gluconate-assimilation                          0.812950  0.830882
# arginine-hydrolysis                             0.677551  0.864583
#
#                                                matthews_corrcoef
# gram_positive-unknown                                   0.957046
# L-rhamnose-fermentation                                 0.923747
# spore_formation-unknown                                 0.875953
# D-mannitol-fermentation                                 0.821249
# myo-inositol-fermentation                               0.816497
# cellobiose-fermentation                                 0.810488
# L-arabinose-fermentation                                0.803773
# melibiose-fermentation                                  0.759186
# D-xylose-builds_acid_from                               0.750580
# decanoate-assimilation                                  0.736434
# D-glucose-fermentation                                  0.734186
# palatinose-builds_acid_from                             0.731925
# L-arabinose-builds_acid_from                            0.705342
# methyl_beta-D-xylopyranoside-builds_acid_from           0.699266
# sorbitol-fermentation                                   0.695649
# amygdalin-fermentation                                  0.685815
# oxygen_tolerance_aerobe-unknown                         0.684778
# tryptophan-energy_source                                0.679924
# gluconate-assimilation                                  0.670286
# arginine-hydrolysis                                     0.669202

# %%
top20_scores_df.groupby("category")["name"].count()
# Out:
# category
# assimilation        2
# builds_acid_from    4
# energy_source       1
# fermentation        9
# hydrolysis          1
# unknown             3
# Name: name, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=top20_scores_df, x="name", y="matthews_corrcoef")
plt.ylim((-1, 1))
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=top20_scores_df, x="name", y="balanced_accuracy")
plt.ylim((0, 1))
plt.xticks(rotation=90);

# %%
import pickle
import numpy as np

# %%
def get_predictors(row: pd.Series, output_folder: pathlib.Path):
    cat = row["category"]
    if cat is np.nan:
        cat = "NA"
    name = row["name"]
    file_path = output_folder / f"{cat}/{name}/phenotype_predictor.pkl"
    with open(file_path, "rb") as f:
        predictor = pickle.load(f)
    return predictor

# %%
top20_scores_df["predictors"] = top20_scores_df.apply(get_predictors, axis=1, args=(output_folder,))

# %%
all_scores_df["predictors"] = all_scores_df.apply(get_predictors, axis=1, args=(output_folder,))

# %%
get_positives = lambda x: x.phenotype.phenotype_data.value_counts().loc[1]
get_negatives = lambda x: x.phenotype.phenotype_data.value_counts().loc[0]

# %%
all_scores_df["positive"] = all_scores_df["predictors"].apply(lambda x: get_positives(x))
all_scores_df["negative"] = all_scores_df["predictors"].apply(lambda x: get_negatives(x))
all_scores_df.drop(columns=["predictors"], inplace=True)

# %%
all_scores_df
# Out:
#                                                  name      category  accuracy  \
# myo-inositol-NA                          myo-inositol           NaN  0.592857
# sucrose-NA                                    sucrose           NaN  0.652778
# glucose-NA                                    glucose           NaN  0.621622
# xylose-NA                                      xylose           NaN  0.571429
# arabinose-NA                                arabinose           NaN  0.737589
# ...                                               ...           ...       ...
# L-histidine-assimilation                  L-histidine  assimilation  0.720930
# raffinose-assimilation                      raffinose  assimilation  0.666667
# acetate-assimilation                          acetate  assimilation  0.739130
# potassium_gluconate-assimilation  potassium_gluconate  assimilation  0.647059
# L-fucose-assimilation                        L-fucose  assimilation  0.538462
#
#                                   balanced_accuracy        f1  precision  \
# myo-inositol-NA                            0.589231  0.551181   0.564516
# sucrose-NA                                 0.637962  0.709302   0.685393
# glucose-NA                                 0.688889  0.735849   0.951220
# xylose-NA                                  0.564626  0.433962   0.359375
# arabinose-NA                               0.733709  0.767296   0.772152
# ...                                             ...       ...        ...
# L-histidine-assimilation                   0.692857  0.600000   0.600000
# raffinose-assimilation                     0.652520  0.533333   0.470588
# acetate-assimilation                       0.739130  0.739130   0.739130
# potassium_gluconate-assimilation           0.660394  0.594595   0.511628
# L-fucose-assimilation                      0.540584  0.400000   0.315789
#
#                                     recall  matthews_corrcoef  positive  \
# myo-inositol-NA                   0.538462           0.179180       214
# sucrose-NA                        0.734940           0.280618       276
# glucose-NA                        0.600000           0.248408       433
# xylose-NA                         0.547619           0.118899       140
# arabinose-NA                      0.762500           0.466558       265
# ...                                    ...                ...       ...
# L-histidine-assimilation          0.600000           0.385714        50
# raffinose-assimilation            0.615385           0.287298        44
# acetate-assimilation              0.739130           0.478261        76
# potassium_gluconate-assimilation  0.709677           0.308843       104
# L-fucose-assimilation             0.545455           0.073076        35
#
#                                   negative
# myo-inositol-NA                        250
# sucrose-NA                             203
# glucose-NA                              59
# xylose-NA                              325
# arabinose-NA                           203
# ...                                    ...
# L-histidine-assimilation                91
# raffinose-assimilation                  94
# acetate-assimilation                    76
# potassium_gluconate-assimilation       177
# L-fucose-assimilation                   94
#
# [245 rows x 10 columns]

# %%
all_scores_df.to_csv(output_folder / "all_scores.csv")

# %%
import shap

# %%
from trait_prediction.utils import read_rast_features

# %%
features, id_dict = read_rast_features("../data/raw/rast_features.tsv")

# %%
predictor = top20_scores_df.iloc[0]["predictors"]
predictor.phenotype.phenotype_data.value_counts().loc[1]
# Out:
# 1259

# %%
def plot_shap_summary(df, name, id_dict):
    predictor = df.loc[name, "predictors"]
    feature_data = predictor.phenotype.feature_data
    clf = predictor.classifier
    feature_labels = [id_dict[c] for c in feature_data.columns]
    explainer = shap.Explainer(clf)
    shap_values = explainer(feature_data)
    shap_values.feature_names = feature_labels
    shap.summary_plot(shap_values, max_display=10, show=False);
    plt.title(f"{predictor.phenotype.name}");
    plt.plot();

# %%
plot_shap_summary(top20_scores_df, "gram_positive-unknown", id_dict)

# %%
top20_scores_df.index
# Out:
# Index(['gram_positive-unknown', 'L-rhamnose-fermentation',
#        'spore_formation-unknown', 'D-mannitol-fermentation',
#        'myo-inositol-fermentation', 'cellobiose-fermentation',
#        'L-arabinose-fermentation', 'melibiose-fermentation',
#        'D-xylose-builds_acid_from', 'decanoate-assimilation',
#        'D-glucose-fermentation', 'palatinose-builds_acid_from',
#        'L-arabinose-builds_acid_from',
#        'methyl_beta-D-xylopyranoside-builds_acid_from',
#        'sorbitol-fermentation', 'amygdalin-fermentation',
#        'oxygen_tolerance_aerobe-unknown', 'tryptophan-energy_source',
#        'gluconate-assimilation', 'arginine-hydrolysis'],
#       dtype='object')

# %%
plot_shap_summary(top20_scores_df, "D-mannitol-fermentation", id_dict)

# %%
plot_shap_summary(all_scores_df, "potassium_gluconate-assimilation", id_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/trait-prediction-HoVPLvWo-py3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/Library/Caches/pypoetry/virtualenvs/trait-prediction-HoVPLvWo-py3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Library/Caches/pypoetry/virtualenvs/trait-prediction-HoVPLvWo-py3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'predictors'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/g8k/Documents/Work/trait-prediction/notebooks/aggregate_ml_results.ipynb Cell 32 line 1
# ----> <a href='vscode-notebook-cell:/Users/g8k/Documents/Work/trait-prediction/notebooks/aggregate_ml_results.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> plot_shap_summary(all_scores_df, "potassium_gluconate-assimilation", id_dict)
#
# /Users/g8k/Documents/Work/trait-prediction/notebooks/aggregate_ml_results.ipynb Cell 32 line 2
#       <a href='vscode-notebook-cell:/Users/g8k/Documents/Work/trait-prediction/notebooks/aggregate_ml_results.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> def plot_shap_summary(df, name, id_dict):
# ----> <a href='vscode-notebook-cell:/Users/g8k/Documents/Work/trait-prediction/notebooks/aggregate_ml_results.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a>     predictor = df.loc[name, "predictors"]
#       <a href='vscode-notebook-cell:/Users/g8k/Documents/Work/trait-prediction/notebooks/aggregate_ml_results.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a>     feature_data = predictor.phenotype.feature_data
#       <a href='vscode-notebook-cell:/Users/g8k/Documents/Work/trait-prediction/notebooks/aggregate_ml_results.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a>     clf = predictor.classifier
#
# File ~/Library/Caches/pypoetry/virtualenvs/trait-prediction-HoVPLvWo-py3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1096, in _LocationIndexer.__getitem__(self, key)
#    1094     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1095     if self._is_scalar_access(key):
# -> 1096         return self.obj._get_value(*key, takeable=self._takeable)
#    1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#
# File ~/Library/Caches/pypoetry/virtualenvs/trait-prediction-HoVPLvWo-py3.11/lib/python3.11/site-packages/pandas/core/frame.py:3870, in DataFrame._get_value(self, index, col, takeable)
#    3867     series = self._ixs(col, axis=1)
#    3868     return series._values[index]
# -> 3870 series = self._get_item_cache(col)
#    3871 engine = self.index._engine
#    3873 if not isinstance(self.index, MultiIndex):
#    3874     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3875     #  results if our categories are integers that dont match our codes
#    3876     # IntervalIndex: IntervalTree has no get_loc
#
# File ~/Library/Caches/pypoetry/virtualenvs/trait-prediction-HoVPLvWo-py3.11/lib/python3.11/site-packages/pandas/core/frame.py:4255, in DataFrame._get_item_cache(self, item)
#    4250 res = cache.get(item)
#    4251 if res is None:
#    4252     # All places that call _get_item_cache have unique columns,
#    4253     #  pending resolution of GH#33047
# -> 4255     loc = self.columns.get_loc(item)
#    4256     res = self._ixs(loc, axis=1)
#    4258     cache[item] = res
#
# File ~/Library/Caches/pypoetry/virtualenvs/trait-prediction-HoVPLvWo-py3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'predictors'
